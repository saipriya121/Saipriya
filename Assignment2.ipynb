# %% [markdown]
# <a href="https://colab.research.google.com/github/saipriya121/Saipriya/blob/main/Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing required libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # **Reading the dataset**

# %%
data = pd.read_csv("/content/insurance.csv")

# %% [markdown]
# # **Understanding the data by performing various operations**

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data.shape
# Out:
# (1338, 7)

# %%
data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
data.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
data["charges"].max()
# Out:
# 63770.42801

# %%
data.nunique()
# Out:
# age           47
# sex            2
# bmi          548
# children       6
# smoker         2
# region         4
# charges     1337
# dtype: int64

# %% [markdown]
# # **Handling null values**

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
data['age'].fillna(data['age'].mean(),inplace=True)

# %% [markdown]
# # **Data Visualization**

# %%
sns.displot(data['age'])

# %%
sns.jointplot(x=data['age'], y=data['bmi'], kind="kde")

# %%
sns.lineplot(x=data['age'], y=data['charges'])
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %% [markdown]
# ## *Checking for outliers*

# %%
sns.boxplot(data['age'])
# Out:
# <Axes: ylabel='age'>

# %% [markdown]
# # **Label Encoding**

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data['sex'] = label_encoder.fit_transform(data['sex'])
data['smoker'] = label_encoder.fit_transform(data['smoker'])
data['region'] = label_encoder.fit_transform(data['region'])

# %%
data.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %% [markdown]
# # **Seperating the data**

# %%
x=data.drop(columns=['charges'],axis=1)
y=data["charges"]
x
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    0  27.900         0       1       3
# 1      18    1  33.770         1       0       2
# 2      28    1  33.000         3       0       2
# 3      33    1  22.705         0       0       1
# 4      32    1  28.880         0       0       1
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    1  30.970         3       0       1
# 1334   18    0  31.920         0       0       0
# 1335   18    0  36.850         0       0       2
# 1336   21    0  25.800         0       0       3
# 1337   61    0  29.070         0       1       1
#
# [1338 rows x 6 columns]

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %% [markdown]
# # **Scaling**

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(x)
X
# Out:
# array([[-1.43876426, -1.0105187 , -0.45332   , -0.90861367,  1.97058663,
#          1.34390459],
#        [-1.50996545,  0.98959079,  0.5096211 , -0.07876719, -0.5074631 ,
#          0.43849455],
#        [-0.79795355,  0.98959079,  0.38330685,  1.58092576, -0.5074631 ,
#          0.43849455],
#        ...,
#        [-1.50996545, -1.0105187 ,  1.0148781 , -0.90861367, -0.5074631 ,
#          0.43849455],
#        [-1.29636188, -1.0105187 , -0.79781341, -0.90861367, -0.5074631 ,
#          1.34390459],
#        [ 1.55168573, -1.0105187 , -0.26138796, -0.90861367,  1.97058663,
#         -0.46691549]])

# %%
X = pd.DataFrame(x)
X
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    0  27.900         0       1       3
# 1      18    1  33.770         1       0       2
# 2      28    1  33.000         3       0       2
# 3      33    1  22.705         0       0       1
# 4      32    1  28.880         0       0       1
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    1  30.970         3       0       1
# 1334   18    0  31.920         0       0       0
# 1335   18    0  36.850         0       0       2
# 1336   21    0  25.800         0       0       3
# 1337   61    0  29.070         0       1       1
#
# [1338 rows x 6 columns]

# %% [markdown]
# # **Splitting the data**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)
x_train.head()
# Out:
#       age  sex     bmi  children  smoker  region
# 621    37    1  34.100         4       1       3
# 194    18    1  34.430         0       0       2
# 240    23    0  36.670         2       1       0
# 1168   32    1  35.200         2       0       3
# 1192   58    0  32.395         1       0       0

# %%
x_test.head()
# Out:
#       age  sex     bmi  children  smoker  region
# 578    52    1  30.200         1       0       3
# 610    47    0  29.370         1       0       2
# 569    48    1  40.565         2       1       1
# 1034   61    1  38.380         0       0       1
# 198    51    0  18.050         0       0       1

# %%
y_train.head()
# Out:
# 621     40182.24600
# 194      1137.46970
# 240     38511.62830
# 1168     4670.64000
# 1192    13019.16105
# Name: charges, dtype: float64

# %%
y_test.head()
# Out:
# 578      9724.53000
# 610      8547.69130
# 569     45702.02235
# 1034    12950.07120
# 198      9644.25250
# Name: charges, dtype: float64

# %% [markdown]
# # **Model Building**

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred= rfr.predict(x_test)
y_pred
# Out:
# array([11120.9096551 ,  9550.8522873 , 44337.4672358 , 13108.34343   ,
#        10923.4884279 , 11917.1311179 ,  2160.772206  , 12776.9467965 ,
#         7790.0307175 ,  5979.6405115 ,  7538.6562657 , 19656.7617004 ,
#         7579.1214762 ,  5539.3009286 , 22314.2320304 , 13094.3568066 ,
#        13303.7892661 , 10878.3018929 ,  6851.665497  , 33949.2361711 ,
#        24001.875643  , 12862.5625894 , 11469.4566724 , 27088.4040905 ,
#         2402.0406918 ,  9730.1751994 ,  6352.2736094 ,  8421.6322288 ,
#         3778.775867  , 12488.9142956 ,  7909.9503502 , 48490.7096961 ,
#        13964.0913038 , 10884.3829922 , 15626.4805637 ,  4126.2997112 ,
#         8844.7122201 , 37484.6304895 , 39470.806634  ,  6941.4347678 ,
#         9818.1922869 ,  3521.5027727 , 21088.9694289 , 46792.951617  ,
#        36871.8439031 ,  4511.1474509 , 13407.1721776 ,  6942.0529209 ,
#         6460.2703454 , 12513.5405778 ,  4896.7674334 , 15494.9209704 ,
# ...

# %%
y_test
# Out:
# 578      9724.53000
# 610      8547.69130
# 569     45702.02235
# 1034    12950.07120
# 198      9644.25250
#            ...
# 1084    15019.76005
# 726      6664.68595
# 1132    20709.02034
# 725     40932.42950
# 963      9500.57305
# Name: charges, Length: 268, dtype: float64

# %%
from sklearn.metrics import r2_score
acc = r2_score(y_pred,y_test)
print(acc*100)
# Out:
# 86.98239324854285

# %% [markdown]
# # **Testing the model**

# %%
rfr.predict([[19,0,27.900,0,1,3]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([17091.5606032])
